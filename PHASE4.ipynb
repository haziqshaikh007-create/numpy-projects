# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
array1 = np.array([[1,2,3],[4,5,6]])
array2 = np.random.random((3,3))
array3 = np.zeros((4,4))

# %%
np.save('array1.npy',array1)
np.save('array2.npy',array2)
np.save('array3.npy',array3)

# %%
loaded_array2 = np.load('array2.npy')
print(loaded_array2)
# Out:
# [[0.66635342 0.14844742 0.79198264]
#  [0.73472225 0.11087289 0.88088963]
#  [0.42875126 0.29208796 0.0552335 ]]

# %%
try:
        logo = np.load('numpy-logo.npy')

        #Display
        plt.Figure(figsize=(10,6)) 
        plt.subplot(121) 
        plt.imshow(logo) 
        plt.title("Numpy Logo") 
        # plt.grid(False) 

        dark_logo = 1 - logo

        plt.subplot(122) 
        plt.imshow(dark_logo) 
        plt.title("Dark Numpy Logo")
        # plt.grid(False) 

except FileNotFoundError:
        
        print("numpy logo file is not found")
